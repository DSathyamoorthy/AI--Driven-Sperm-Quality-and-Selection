# %%
pip install ultralytics opencv-python-headless pillow pandas streamlit

# %%
from ultralytics import YOLO

# Load base YOLOv8 small model
model = YOLO("yolov8s.pt")  # or "yolov8n.pt" for tiny

# Train on your dataset
model.train(
    data="data.yaml",      # path to your data.yml
    epochs=50,            # can adjust
    imgsz=256,            # image size
    batch=16,             # batch size
    name="Morphology final.v1i.yolov8"  # folder name to save results
)

# %%
import os
print(os.getcwd())  # current folder
print(os.listdir())  # list files in current folder

# %%
from ultralytics import YOLO
import os

# Make sure we are in the folder containing data.yaml
os.chdir(r"D:\Morphology final.v1i.yolov8")  # replace with your folder

# Load base model
model = YOLO("yolov8s.pt")

# Train
model.train(
    data="data.yaml",       # your dataset yaml
    epochs=50,
    imgsz=256,
    batch=16,
    name="Morphology final.v1i.yolov8"  # folder to save results
)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import files
import zipfile

uploaded = files.upload()  # upload a zip of your dataset

# %%
with zipfile.ZipFile("Morphology final.v1i.yolov8.zip","r") as zip_ref:
    zip_ref.extractall("/content/Morphology_final")

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os

# Change working directory to your dataset folder
os.chdir("/content/Morphology_final")

# Load base model
model = YOLO("yolov8s.pt")

# Train on your dataset
model.train(
    data="data.yaml",       # path to data.yaml inside your folder
    epochs=50,
    imgsz=256,
    batch=16,
    name="morphology_local"  # folder to save weights
)

# %%
# !cp /content/runs/train/morphology_local/weights/best.pt /content/drive/MyDrive/Morphology_weights/morphology_best.pt

# %%
# !zip -r morphology_final.zip /content/Morphology_final

# %%
from google.colab import files
files.download("morphology_final.zip")

# %%
from google.colab import files
uploaded = files.upload()

# %%
import zipfile
import os

zip_path = list(uploaded.keys())[0]  # get uploaded file name

# Extract zip
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content')

print("Extracted to /content")

# %%
# !ls /content

# %%
# !ls "/content/motility-final.v1i.yolov8"

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/motility-final.v1i.yolov8/data.yaml",
    epochs=50,
    imgsz=256,
    batch=16,
    name="motility_model"
)

# %%
import os

target_folder = "/content/motility_dataset"
os.makedirs(target_folder, exist_ok=True)

print("Created:", target_folder)

# %%
import zipfile

zip_name = list(uploaded.keys())[0]  # get uploaded file name
zip_path = f"/content/{zip_name}"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(target_folder)

print("Unzipped to:", target_folder)

# %%
zip_name = "motility.zip"   # <-- change if different
zip_path = f"/content/Morphology final.v1i.yolov8.zip"

# %%
import shutil
shutil.move(zip_path, target_folder)

# %%
import zipfile

zip_in_folder = f"{target_folder}/{zip_name}"

with zipfile.ZipFile(zip_in_folder, 'r') as zip_ref:
    zip_ref.extractall(target_folder)

print("Unzipped inside:", target_folder)

# %%
# !ls /content

# %%
# !ls /content/motility_dataset

# %%
import os
target_folder = "/content/motility_dataset"
os.makedirs(target_folder, exist_ok=True)

print("Created:", target_folder)

# %%
import zipfile

zip_path = "/content/Sperm Head Detection - Final.v1i.yolov8-obb.zip"
extract_to = "/content/motility_dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("Unzip complete!")

# %%
# !ls -1 /content

# %%
# !ls -1 /content

# %%
import os

target_folder = "/content/motility_v1"
os.makedirs(target_folder, exist_ok=True)

# !echo "Target folder created at: {target_folder}"

# %%
zip_name = "Sperm Head Detection - Final.v1i.yolov8-obb.zip"
source_path = f"/content/{zip_name}"
target_path = f"/content/motility_v1/{zip_name}"

# !mv "$source_path" "$target_path"
# !echo "Moved ZIP file to: $target_path"

# %%
import zipfile

zip_path = f"/content/motility_v1/{zip_name}"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/motility_v1")

print("Unzipped successfully into /content/motility_v1")

# %%
# !ls /content/motility_v1

# %%
data_yaml = """
train: /content/motility_v1/train/images
val: /content/motility_v1/valid/images
test: /content/motility_v1/test/images

nc: 1
names: ['motility']
"""

with open("/content/motility_v1/data.yaml", "w") as f:
    f.write(data_yaml)

print("data.yaml created successfully!")

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  # base model

model.train(
    data="/content/motility_v1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
)
